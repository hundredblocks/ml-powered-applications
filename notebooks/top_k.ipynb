# %% [markdown]
# # The top k approach

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

import sys
sys.path.append("..")

from ml_editor.data_processing import format_raw_df

data_path = Path('../data/writers.csv')
df = pd.read_csv(data_path)
df = format_raw_df(df.copy())
# Out:
# /Users/emmanuel.ameisen/ml_editor/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
from ml_editor.data_processing import get_split_by_author, get_vectorized_inputs_and_label, add_features_to_df

df = add_features_to_df(df.loc[df["is_question"]].copy(), pretrained_vectors=True)
train_df, test_df = get_split_by_author(df, test_size=0.2, random_state=40)

# %%
X_train, y_train = get_vectorized_inputs_and_label(train_df)
X_test, y_test = get_vectorized_inputs_and_label(test_df)

# %%
from sklearn.externals import joblib

model_path = Path("../models/model_1.pkl")
clf = joblib.load(model_path) 

y_predicted = clf.predict(X_test)
y_predicted_proba = clf.predict_proba(X_test)

# %%
from ml_editor.model_evaluation import get_top_k

test_analysis_df = test_df.copy()
test_analysis_df["predicted_proba"] = y_predicted_proba[:, 1]
test_analysis_df["true_label"] = y_test

to_display = [
    "predicted_proba",
    "true_label",
    "Title",
    "body_text",
    "text_len",
    "action_verb_full",
    "question_mark_full",
    "language_question",
]
threshold = 0.5


top_pos, top_neg, worst_pos, worst_neg, unsure = get_top_k(test_analysis_df, "predicted_proba", "true_label", k=2)
pd.options.display.max_colwidth = 100

# %%
# Most confident correct positive predictions
top_pos[to_display]
# Out:
#        predicted_proba  true_label  \
# Id
# 38394             0.82        True
# 24729             0.79        True
#
#                                                                                                      Title  \
# Id
# 38394  Are chapters with a single character inherently more difficult for an average reader to connect ...
# 24729                                  Can I use "fuck" as a non-vulgar verb in a fantasy/steampunk world?
#
#                                                                                                  body_text  \
# Id
# 38394  On the topic of keeping a reader engaged:\nDialog is a great way to balance out a scene of descr...
# 24729  I've been sending my fourth-ish novel through the my writing group. It is about a trio of teenag...
#
#        text_len  action_verb_full  question_mark_full  language_question
# Id
# 38394       511              True                True              False
# 24729       397              True                True              False

# %%
# Most confident correct negative predictions
top_neg[to_display]
# Out:
#       predicted_proba  true_label  \
# Id
# 7878             0.22       False
# 8204             0.24       False
#
#                                                                                                     Title  \
# Id
# 7878  When quoting a person's informal speech, how much liberty do you have to make changes to what th...
# 8204                                                              Separate paragraphs without line breaks
#
#                                                                                                 body_text  \
# Id
# 7878  Even during a formal interview for a news article, people speak informally. They say "uhm", they...
# 8204  I have a medium which does not have line breaks, and a few paragraphs of text. How can I separat...
#
#       text_len  action_verb_full  question_mark_full  language_question
# Id
# 7878       116              True                True              False
# 8204       217              True                True              False

# %%
# Most confident incorrect negative predictions
worst_pos[to_display]
# Out:
#        predicted_proba  true_label  \
# Id
# 18613             0.22        True
# 19509             0.27        True
#
#                                                                            Title  \
# Id
# 18613  Addressing "logo-ification" of an organization's name in their literature
# 19509                    How to copyright a book without lawyer and outside USA?
#
#                                                                                                  body_text  \
# Id
# 18613  I need help finding some style rules to address an issue with a client. I'm working with an orga...
# 19509  I would like to publish an ebook with amazon and i dont have time/money to keep copyrights with ...
#
#        text_len  action_verb_full  question_mark_full  language_question
# Id
# 18613       230             False                True              False
# 19509        56              True                True              False

# %%
# Most confident incorrect positive predictions
worst_neg[to_display]
# Out:
#        predicted_proba  true_label  \
# Id
# 39613             0.79       False
# 4107              0.75       False
#
#                                                                      Title  \
# Id
# 39613  How to write an interview-style story without it being an infodump?
# 4107                    Single character POV vs. two POVs - how to decide?
#
#                                                                                                  body_text  \
# Id
# 39613  Inspired by the Underworld setting where vampires slept in steampunk-styled sarcophagi, slowly d...
# 4107   I'm starting to look at my next novel, and I'm trying to decide whether I should tell it from on...
#
#        text_len  action_verb_full  question_mark_full  language_question
# Id
# 39613       489              True                True              False
# 4107        281              True                True              False

# %%
# Most unsure questions
unsure[to_display]
# Out:
#       predicted_proba  true_label  \
# Id
# 8271              0.5        True
# 8306              0.5       False
#
#                                              Title  \
# Id
# 8271                  About the Author description
# 8306  Publishing price comparisons. Is it allowed?
#
#                                                                                                 body_text  \
# Id
# 8271  Whether we like it or not, the "About the Author" description is a marketing tool. It contains s...
# 8306  I'm currently in the process of writing a small localised book on arranging funerals yourself (D...
#
#       text_len  action_verb_full  question_mark_full  language_question
# Id
# 8271       149             False                True              False
# 8306       166             False                True              False
